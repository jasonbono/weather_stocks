# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## get and clean the weather Data

# %%
#read in the raw stock data
basedir = '/Users/bono/demo_projects/weather_stocks/'
file = basedir+'data/noaa_requests/centralpark2000_all.txt' 
df_weather = pd.read_csv(file)
#convert to datetime and remove the time
df_weather['DATE'] =  pd.to_datetime(df_weather['DATE'])
#index by date
df_weather.set_index('DATE',inplace=True)
df_weather
# Out:
#                 STATION                         NAME  ACMH ACMH_ATTRIBUTES  \
# DATE
# 1940-01-01  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 1940-01-02  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 1940-01-03  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 1940-01-04  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 1940-01-05  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# ...                 ...                          ...   ...             ...
# 2020-02-06  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 2020-02-07  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 2020-02-08  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 2020-02-09  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
# 2020-02-10  USW00094728  NY CITY CENTRAL PARK, NY US   NaN             NaN
#
#             ACSH ACSH_ATTRIBUTES  AWND AWND_ATTRIBUTES  PRCP PRCP_ATTRIBUTES  \
# DATE
# 1940-01-01   NaN             NaN   NaN             NaN  0.00             ,,0
# 1940-01-02   NaN             NaN   NaN             NaN  0.00             ,,0
# 1940-01-03   NaN             NaN   NaN             NaN  0.00             ,,0
# 1940-01-04   NaN             NaN   NaN             NaN  0.00             ,,0
# 1940-01-05   NaN             NaN   NaN             NaN  0.03             ,,0
# ...          ...             ...   ...             ...   ...             ...
# 2020-02-06   NaN             NaN  6.93             ,,W  0.51             ,,D
# 2020-02-07   NaN             NaN  9.62             ,,W  0.25             ,,D
# 2020-02-08   NaN             NaN  7.38             ,,W  0.00             ,,D
# 2020-02-09   NaN             NaN  5.82             ,,W  0.00             ,,D
# 2020-02-10   NaN             NaN  6.26             ,,W  0.37             ,,D
#
#             ...  WT17 WT17_ATTRIBUTES  WT18 WT18_ATTRIBUTES  WT19  \
# DATE        ...
# 1940-01-01  ...   NaN             NaN   NaN             NaN   NaN
# 1940-01-02  ...   NaN             NaN   NaN             NaN   NaN
# 1940-01-03  ...   NaN             NaN   NaN             NaN   NaN
# 1940-01-04  ...   NaN             NaN   NaN             NaN   NaN
# 1940-01-05  ...   NaN             NaN   NaN             NaN   NaN
# ...         ...   ...             ...   ...             ...   ...
# 2020-02-06  ...   NaN             NaN   NaN             NaN   NaN
# 2020-02-07  ...   NaN             NaN   NaN             NaN   NaN
# 2020-02-08  ...   NaN             NaN   NaN             NaN   NaN
# 2020-02-09  ...   NaN             NaN   NaN             NaN   NaN
# 2020-02-10  ...   NaN             NaN   NaN             NaN   NaN
#
#            WT19_ATTRIBUTES  WT21 WT21_ATTRIBUTES  WT22 WT22_ATTRIBUTES
# DATE
# 1940-01-01             NaN   NaN             NaN   NaN             NaN
# 1940-01-02             NaN   NaN             NaN   NaN             NaN
# 1940-01-03             NaN   NaN             NaN   NaN             NaN
# 1940-01-04             NaN   NaN             NaN   NaN             NaN
# 1940-01-05             NaN   NaN             NaN   NaN             NaN
# ...                    ...   ...             ...   ...             ...
# 2020-02-06             NaN   NaN             NaN   NaN             NaN
# 2020-02-07             NaN   NaN             NaN   NaN             NaN
# 2020-02-08             NaN   NaN             NaN   NaN             NaN
# 2020-02-09             NaN   NaN             NaN   NaN             NaN
# 2020-02-10             NaN   NaN             NaN   NaN             NaN
#
# [29261 rows x 66 columns]

# %%
basedir = '/Users/bono/demo_projects/weather_stocks/'
file = basedir+'data/df_weather_alt.pkl'
df_weather.to_pickle(file)
